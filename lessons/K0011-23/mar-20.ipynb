# %%
import csv

# %%
with open('/home/gleb/Documents/Python/Python-2/Python-2/lessons/K0609-22/titanic.csv') as f:
    reader = csv.reader(f)

    for row in reader:
        print(row)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# ['1', '0', '3', 'Braund, Mr. Owen Harris', 'male', '22', '1', '0', 'A/5 21171', '7.25', '', 'S']
# ['2', '1', '1', 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', '38', '1', '0', 'PC 17599', '71.2833', 'C85', 'C']
# ['3', '1', '3', 'Heikkinen, Miss. Laina', 'female', '26', '0', '0', 'STON/O2. 3101282', '7.925', '', 'S']
# ['4', '1', '1', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', '35', '1', '0', '113803', '53.1', 'C123', 'S']
# ['5', '0', '3', 'Allen, Mr. William Henry', 'male', '35', '0', '0', '373450', '8.05', '', 'S']
# ['6', '0', '3', 'Moran, Mr. James', 'male', '', '0', '0', '330877', '8.4583', '', 'Q']
# ['7', '0', '1', 'McCarthy, Mr. Timothy J', 'male', '54', '0', '0', '17463', '51.8625', 'E46', 'S']
# ['8', '0', '3', 'Palsson, Master. Gosta Leonard', 'male', '2', '3', '1', '349909', '21.075', '', 'S']
# ...

# %%
with open('/home/gleb/Documents/Python/Python-2/Python-2/lessons/K0609-22/titanic.csv') as f:
    reader = csv.DictReader(f)

    for row in reader:
        print(row['Name'], row['Age'], row['Survived'])
# Out:
# Braund, Mr. Owen Harris 22 0
# Cumings, Mrs. John Bradley (Florence Briggs Thayer) 38 1
# Heikkinen, Miss. Laina 26 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel) 35 1
# Allen, Mr. William Henry 35 0
# Moran, Mr. James  0
# McCarthy, Mr. Timothy J 54 0
# Palsson, Master. Gosta Leonard 2 0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg) 27 1
# Nasser, Mrs. Nicholas (Adele Achem) 14 1
# Sandstrom, Miss. Marguerite Rut 4 1
# Bonnell, Miss. Elizabeth 58 1
# Saundercock, Mr. William Henry 20 0
# Andersson, Mr. Anders Johan 39 0
# Vestrom, Miss. Hulda Amanda Adolfina 14 0
# Hewlett, Mrs. (Mary D Kingcome)  55 1
# Rice, Master. Eugene 2 0
# Williams, Mr. Charles Eugene  1
# Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele) 31 0
# Masselmani, Mrs. Fatima  1
# Fynney, Mr. Joseph J 35 0
# Beesley, Mr. Lawrence 34 1
# McGowan, Miss. Anna "Annie" 15 1
# Sloper, Mr. William Thompson 28 1
# Palsson, Miss. Torborg Danira 8 0
# ...
